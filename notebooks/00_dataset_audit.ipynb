# %% [markdown]
# # Dataset Audit
#
# This notebook is a lightweight entry point. The executable audit lives in `scripts/audit_datasets.py` so the evidence gate can be run in CI and from the command line.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve() / 'src'))
from rewirescope.audit import load_source_registry, registry_rows
registry_rows(load_source_registry('../data/metadata/source_buildability.yml'))
